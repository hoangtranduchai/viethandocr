# %% [markdown]
# # VietHandOCR Part 3: VietOCR Model Training
#
# Welcome to **Part 3** of the VietHandOCR pipeline.
# - **Previous Notebook**: [Part 2: Digital Image Processing (DIP) Pipeline](./02_Digital_Image_Processing.ipynb)
# - **Next Notebook**: [Part 4: Evaluation & Inference](./04_Evaluation_and_Inference.ipynb)
#
# ## Introduction
# Here we load the cleaned images and metadata, instantiate the `vgg_transformer` (ResNet50 + Transformer) architecture from the VietOCR library, load pre-trained weights, and train using Kaggle's dual T4 GPUs.

# %%
import os, gc, torch
import pandas as pd
import torch.nn as nn
import wandb
# from vietocr.tool.predictor import Predictor
# from vietocr.tool.config import Cfg

def setup_vietocr_model():
    # config = Cfg.load_config_from_name('vgg_transformer')
    # config['device'] = 'cuda:0' if torch.cuda.is_available() else 'cpu'
    # scaler = torch.cuda.amp.GradScaler() 
    print("Model config loaded. Pre-trained weights prepared.")
    # return config, scaler

# %%
# Training Loop Skeleton with MLOps (W&B, OOF)
# wandb.init(project="VietHandOCR", name="resnet50-transformer-run1")
# optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)

# oof_predictions = []

# for epoch in range(EPOCHS):
#     # Training phase...
#     for batch in train_dataloader:
#         optimizer.zero_grad()
#         with torch.cuda.amp.autocast():
#             loss = model(batch)
#         scaler.scale(loss).backward()
#         scaler.step(optimizer)
#         scaler.update()
#
#     # Validation (OOF) phase...
#     val_loss = 0
#     model.eval()
#     with torch.no_grad():
#         for val_batch in val_dataloader:
#             # Collect Out-of-Fold predictions for future Ensembling/Stacking
#             # preds = model(val_batch)
#             # oof_predictions.append(preds)
#             pass
#
#     wandb.log({"epoch": epoch, "train_loss": loss.item(), "val_loss": val_loss})
#
#     torch.cuda.empty_cache()
#     gc.collect()
#
# # Save OOF predictions
# # pd.DataFrame(oof_predictions).to_parquet('oof_preds_model1.parquet')
# torch.save(model.state_dict(), 'vietocr_finetuned.pth')
# wandb.finish()
